# %% [markdown]
# <font size= 5>&emsp;EEGLab is a widely used environment for human brain signals analysis.
#
# <font size= 5>&emsp;In this section, I try to be familiar with it, as a total beginner in EEG.
#
# <font size= 5>&emsp;The idea that motivates me is that electroencephalogram is fantastic. BCI, cyberpunk, cool!
#
# <font size= 5>   &emsp; And to be honest, its electrode array on the head is referring to the question of optimization in the parameter hypersurface of sensors array, correlated with I am trying to dig out in my research area. The manifold analysis might have the potential on it.

# %% [markdown]
# ![1.jpg](attachment:1.jpg)
# <font size= 4> Starting EEGlab from command line of Matlab

# %% [markdown]
# ![4.jpg](attachment:4.jpg)
# <font size= 4> Reading datasets of BCI competition 2008 from matlab.

# %% [markdown]
# ![6.jpg](attachment:6.jpg)
# <font size= 4> Choosing appropriate sub-dataset, appling 1hz low bandpass filter to remove artifact.

# %% [markdown]
# ![7.jpg](attachment:7.jpg)![10.jpg](attachment:10.jpg)
# <font size =4> This dataset is about motor imaginary. The action trials and labels were separated in original dataset. So it is necessary to concatenate them into another channel for EEGlab identification.

# %% [markdown]
# ![9.jpg](attachment:9.jpg)
# <font size =4> Concatenate data array.

# %% [markdown]
# ![12.jpg](attachment:12.jpg)
# <font size =4> The interface could recognize the event timing now!

# %% [markdown]
# ![13.jpg](attachment:13.jpg)
# <font size =4> Plotting channel spectra and map.
